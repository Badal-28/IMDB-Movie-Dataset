# %% [markdown]
# <a href="https://colab.research.google.com/github/Badal-28/IMDB-Movie-Dataset/blob/main/DS/Project%20-%209%20IMDB%20Movie%20Dataset%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/PromptCloudHQ/imdb-data

# %% [markdown]
# ### IMDB data from 2006 to 2016

# %% [raw]
# Here's a data set of 1,000 most popular movies on IMDB in the last 10 years. The data points included are:
#
# Title, Genre, Description, Director, Actors, Year, Runtime, Rating, Votes, Revenue, Metascrore

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('IMDB-Movie-Data.csv')

# %% [markdown]
# ### 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (1000, 12)

# %%
print(data.shape[0],"\n",data.shape[1])
# Out:
# 1000
#  12

# %% [markdown]
# ### 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# ### 5. Check Missing Values In The Dataset

# %%
data.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %% [markdown]
# ### 6. Drop All The  Missing Values

# %%
data.dropna(axis=0)
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### 7. Check For Duplicate Data

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
print("Are there any duplicate values?",bool(data.duplicated().sum()))
# Out:
# Are there any duplicate values? False

# %% [markdown]
# ### 8. Get Overall Statistics About The DataFrame

# %%
data.describe(

)
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# ### 9. Display Title of The Movie Having Runtime >= 180 Minutes

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# ### 10. In Which Year There Was The Highest Average Voting?

# %%
x1=data.groupby('Year')['Votes'].mean()
x1
# Out:
# Year
# 2006    269289.954545
# 2007    244331.037736
# 2008    275505.384615
# 2009    255780.647059
# 2010    252782.316667
# 2011    240790.301587
# 2012    285226.093750
# 2013    219049.648352
# 2014    203930.224490
# 2015    115726.220472
# 2016     48591.754209
# Name: Votes, dtype: float64

# %%
sns.barplot(data=data,x='Year',y='Votes')
# Out:
# <Axes: xlabel='Year', ylabel='Votes'>

# %% [markdown]
# ### 11. In Which Year There Was The Highest Average Revenue?

# %%
er=data.groupby('Year')['Revenue (Millions)'].mean()
er
# Out:
# Year
# 2006     86.296667
# 2007     87.882245
# 2008     99.082745
# 2009    112.601277
# 2010    105.081579
# 2011     87.612258
# 2012    107.973281
# 2013     87.121818
# 2014     85.078723
# 2015     78.355044
# 2016     54.690976
# Name: Revenue (Millions), dtype: float64

# %%
sns.barplot(data=data,x='Year',y='Revenue (Millions)',palette='viridis')
plt.title('Revenue by years')
# Out:
# <ipython-input-59-8cf3e1e8217a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x='Year',y='Revenue (Millions)',palette='viridis')
# Text(0.5, 1.0, 'Revenue by years')

# %% [markdown]
# ### 12. Find The Average Rating For Each Director

# %%
data.groupby('Director')['Rating'].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# ### 13. Display Top 10 Lengthy Movies Title and Runtime

# %%
s=data.sort_values(by='Runtime (Minutes)',ascending=False)[['Title','Runtime (Minutes)']]
s
# Out:
#                        Title  Runtime (Minutes)
# 828               Grindhouse                191
# 88         The Hateful Eight                187
# 965            Inland Empire                180
# 311           La vie d'Adèle                180
# 82   The Wolf of Wall Street                180
# ..                       ...                ...
# 711          La tortue rouge                 80
# 949                    Kicks                 80
# 42   Don't Fuck in the Woods                 73
# 819       Wolves at the Door                 73
# 793      Ma vie de Courgette                 66
#
# [1000 rows x 2 columns]

# %%
sns.barplot(data=s.head(10),x='Runtime (Minutes)',y='Title',palette='viridis')
# Out:
# <ipython-input-66-8f17b6d8308a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=s.head(10),x='Runtime (Minutes)',y='Title',palette='viridis')
# <Axes: xlabel='Runtime (Minutes)', ylabel='Title'>

# %% [markdown]
# ### 14. Display Number of Movies Per Year

# %%
data.groupby('Year')['Title'].count()
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Title, dtype: int64

# %%
sns.countplot(data=data,x='Year',palette='viridis')
# Out:
# <ipython-input-71-9d7c4d1125b1>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data,x='Year',palette='viridis')
# <Axes: xlabel='Year', ylabel='count'>

# %% [markdown]
# ### 15. Find Most Popular Movie Title (Higest Revenue)

# %%
data[data['Revenue (Millions)']==max(data['Revenue (Millions)'])]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# ### 16. Display Top 10 Highest Rated Movie Titles And its Directors

# %%
a=data.sort_values('Rating',ascending=False)[['Title','Director','Rating']].head(10)
a
# Out:
#                 Title           Director  Rating
# 54    The Dark Knight  Christopher Nolan     9.0
# 80          Inception  Christopher Nolan     8.8
# 117            Dangal      Nitesh Tiwari     8.8
# 36       Interstellar  Christopher Nolan     8.6
# 96      Kimi no na wa     Makoto Shinkai     8.6
# 249  The Intouchables    Olivier Nakache     8.6
# 133          Whiplash    Damien Chazelle     8.5
# 64       The Prestige  Christopher Nolan     8.5
# 99       The Departed    Martin Scorsese     8.5
# 991  Taare Zameen Par         Aamir Khan     8.5

# %%
sns.barplot(data=data,x='Rating',y=a['Title'])
# Out:
# <Axes: xlabel='Rating', ylabel='Title'>

# %% [markdown]
# ### 17. Display Top 10 Highest Revenue Movie Titles

# %%
ap=data.sort_values(by='Revenue (Millions)',ascending=False)[['Title','Revenue (Millions)']].head(10)
ap
# Out:
#                                           Title  Revenue (Millions)
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 87                                       Avatar              760.51
# 85                               Jurassic World              652.18
# 76                                 The Avengers              623.28
# 54                              The Dark Knight              533.32
# 12                                    Rogue One              532.17
# 119                                Finding Dory              486.29
# 94                      Avengers: Age of Ultron              458.99
# 124                       The Dark Knight Rises              448.13
# 578             The Hunger Games: Catching Fire              424.65

# %%
sns.barplot(data=ap,x='Revenue (Millions)',y='Title')
# Out:
# <Axes: xlabel='Revenue (Millions)', ylabel='Title'>

# %% [markdown]
# ### 18.  Find Average Rating of Movies Year Wise

# %%
data.groupby('Year')['Rating'].mean()
# Out:
# Year
# 2006    7.125000
# 2007    7.133962
# 2008    6.784615
# 2009    6.960784
# 2010    6.826667
# 2011    6.838095
# 2012    6.925000
# 2013    6.812088
# 2014    6.837755
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %% [markdown]
# ### 19. Does Rating Affect The Revenue?

# %%
sns.scatterplot(data=data,x='Rating',y='Revenue (Millions)')
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# ### 20. Classify Movies Based on Ratings [Excellent, Good and Average]

# %%
# Categorizing the ratings using apply()
data['rat_cat'] = data['Rating'].apply(lambda i: 'Excellent' if i >= 7 else ('Good' if i >= 4.5 else 'Avg'))

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### 21. Count Number of Action Movies

# %%
len(data[data['Genre'].str.contains('action',case=False)])
# Out:
# 303

# %% [markdown]
# ### 22. Find Unique Values From Genre

# %%
l=data['Genre']
l
w1=[]
for i in l:
  z=i.split(',')
  for j in z:
    w1.append(j)
from collections import Counter
s=Counter(w1)
t=list(s.keys())
t
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Crime',
#  'Western',
#  'War',
#  'Musical',
#  'Sport']

# %% [markdown]
# ### 23. How Many Films of Each Genre Were Made?

# %%
s
# Out:
# Counter({'Action': 303,
#          'Adventure': 259,
#          'Sci-Fi': 120,
#          'Mystery': 106,
#          'Horror': 119,
#          'Thriller': 195,
#          'Animation': 49,
#          'Comedy': 279,
#          'Family': 51,
#          'Fantasy': 101,
#          'Drama': 513,
#          'Music': 16,
#          'Biography': 81,
#          'Romance': 141,
#          'History': 29,
#          'Crime': 150,
#          'Western': 7,
#          'War': 13,
#          'Musical': 5,
#          'Sport': 18})
